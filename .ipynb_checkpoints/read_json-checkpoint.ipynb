# %%
df = (pd.read_json('/Users/kimia/Downloads/uuids_check_stability_ALL_2.json/json.json', lines=True))
def stablechecker(in_stable):
    try: 

        if int(in_stable) == 1:
            return 'stable'
        elif int(in_stable) == 0:
            return 'edge'
        
    except: 
        print(in_stable)
        #print('nah')
    

df['status'] = df['in_stable'].apply(stablechecker)
df.to_csv('USstable.csv')
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df.to_csv('US')
# Out:
#                        address               city  in_stable   latitude  \
# 0       685 Camp Gettysburg Rd         Gettysburg        1.0        NaN
# 1                 37 S Hunt Rd           Amesbury        1.0        NaN
# 2              577 Crawford St          Fitchburg        1.0        NaN
# 3                 85 Hudson Rd               Stow        1.0        NaN
# 4          13645 Foothill Blvd             Sylmar        1.0        NaN
# 5                  7188 Skyway           Paradise        1.0  39.765717
# 6                 11 W 69th St           New York        1.0  40.774676
# 7           626 Lake Dillon Dr             Dillon        1.0  39.627177
# 8      10807 New Allegiance Dr   Colorado Springs        0.0        NaN
# 9            1619 Lakeshore Dr       Fort Collins        1.0        NaN
# 10                5000 Robb St        Wheat Ridge        1.0        NaN
# 11         4305 University Ave          San Diego        0.0        NaN
# ...

# %%
df[0] = df[0].apply(lambda x: str(x))

# %%
file = 'part-00000-9cfd86a2-887f-4134-ad66-305edcfc3505.json'

# %%
with open('/Users/kimia/Downloads/jsonfilenames.txt.rtf/' + str(file)) as f:
    for line in f:
        try:
            data.update(json.loads( line.rstrip('\n'))) 
            all_df.append(data)
# Out:
#   File "<ipython-input-23-b40d15483d1f>", line 7
#     all_df.append(data)
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.read_csv('~/Downloads/LA_resolved.csv')

def stablechecker(in_stable):
    try: 

        if int(in_stable) == 1:
            return 'stable'
        elif int(in_stable) == 0:
            return 'edge'
        
    except: 
        print(in_stable)
        #print('nah')
    

df['status'] = df['in_stable'].apply(stablechecker)
df.to_csv('LARESOLVED.csv')
# Out:
# nan
# nan
# nan
# nan
# nan

# %%
df['ADD'] = df['address'] + ", " + df["city"] + ", " + df["state"]

# %%
df.to_csv('cleanadd.csv')

# %%
df = pd.read_csv('~/Documents/LA Resolved - Sheet1.csv')
df2 = pd.read_csv('~/Downloads/LA_resolved - cleanadd uuid.csv')

# %%
df3 = pd.merge(df2, df, on='uuid')
df3.to_csv('final_resolved_la.csv')

# %%
print(df3.isnull().sum(axis=0))
# Out:
# address           6
# city              5
# in_stable         5
# name              5
# state             5
# uuid              0
# zip               5
# status            5
# full_address_x    6
# Lat_x             6
# Lng_x             6
# full_address_y    6
# Lat_y             6
# Lng_y             6
# dtype: int64

# %%
df3.Lat = df3['Lat_x']
df3.Lng = df3['Lng_x']
df3 = df3[['Lat', 'Lng', 'status']]
pd.read_csv()
# Out:
#                       address              city  in_stable  \
# 0              413 Via Malaga     Redondo Beach        0.0
# 1         10918 Shoemaker Ave  Santa Fe Springs        1.0
# 2           7958 Beverly Blvd       Los Angeles        1.0
# 3           18825 Railroad St  City Of Industry        0.0
# 4          9619 Klingerman St    South El Monte        1.0
# 5       5515 San Vicente Blvd       Los Angeles        1.0
# 6           9830 Norwalk Blvd  Santa Fe Springs        1.0
# 7              6326 West Blvd       Los Angeles        1.0
# 8            5534 Flotilla St          Commerce        1.0
# 9     11522 W Washington Blvd       Los Angeles        1.0
# 10                   130TH St           Gardena        0.0
# 11             1480 Canal Ave        Long Beach        1.0
# 12           385 Van Ness Ave          Torrance        1.0
# 13           385 Van Ness Ave          Torrance        1.0
# 14           385 Van Ness Ave          Torrance        1.0
# ...
